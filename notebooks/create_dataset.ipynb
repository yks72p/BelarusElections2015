# %% [markdown]
# ### imports

# %%
import os
import pandas as pd

# widget for convenient view of dataframes
import qgrid
from qgrid import show_grid as sg
qgrid.set_grid_option('forceFitColumns', False)
qgrid.set_grid_option('defaultColumnWidth', 180)
qgrid.set_defaults(show_toolbar=True)

# %% [markdown]
# ### read data from `.xlsx`

# %%
colnames_map = {
    'Раён': 'district',
    'Гайдукевіч, N': 'H_n',
    'Гайдукевіч, %': 'H_%',
    'Караткевіч, N': 'K_n',
    'Караткевіч, %': 'K_%',
    'Лукашэнка, N': 'L_n',
    'Лукашэнка, %': 'L_%',
    'Улаховіч, N': 'U_n',
    'Улаховіч, %': 'U_%',
    'выбарцы агулам': 'electors',
    'новыя выбарцы': 'new_electors',
    'атрыманыя бюлетэні': 'ballots',
    'прынялі, N': 'voted_n',
    'прынялі, %': 'voted_%',
    'датэрмінова': 'early_voters',
    'па месцы знаходжання': 'home_voters',
    'на ўчастку': 'pp_voters',  # polling place voters
    'супраць усіх': 'against_all',
    'несапраўдныя бюлетэні': 'spoilt',
}

# %%
fp = os.path.join('..', 'data', 'original', 'Vybary_2015_rajonnaja_statystyka.xlsx')

region_sheets = [
    'Miensk',
    'Mienskaja_voblasc', 'Bresckaja_voblasc', 'Haradzienskaja_voblasc',
    'Viciebskaja_voblasc', 'Mahiliouskaja_voblasc', 'Homielskaja_voblasc',
    'Respublika'
]

dfs = []
for region in region_sheets:
    cur_df = pd.read_excel(fp, sheet_name=region, skiprows=9, na_values='-')
    cur_df.rename(colnames_map, axis=1, inplace=True)
    cur_df['region'] = region
    dfs.append(cur_df)
df = pd.concat(dfs, axis=0, ignore_index=True)
df.shape
# Out:
# (161, 20)

# %% [markdown]
# * map region names

# %%
regions_map = {
    'Miensk': 'г. Менск',
    'Mienskaja_voblasc': 'Менская вобласць',
    'Bresckaja_voblasc': 'Брэсцкая вобласць',
    'Haradzienskaja_voblasc': 'Гарадзенская вобласць',
    'Viciebskaja_voblasc': 'Віцебская вобласць',
    'Mahiliouskaja_voblasc': 'Магілёўская вобласць',
    'Homielskaja_voblasc': 'Гомельская вобласць',
    'Respublika': 'Рэспубліка'
}
df['region'] = df['region'].map(regions_map)

# %% [markdown]
# * add `district_type` column

# %%
df['district_type'] = 'раён'
df.loc[df['district'].str.contains('г\.'), 'district_type'] = 'раён гораду'
df.loc[df['district'].str.contains('^г\.'), 'district_type'] = 'горад'
df.loc[df['region'] == 'г. Менск', 'district_type'] = 'раён гораду'

df.loc[df['district'] == 'Агулам', 'district_type'] = 'Агулам'
df.loc[df['region'] == 'Рэспубліка', 'district_type'] = 'Агулам'

# %% [markdown]
# * move some columns to the beginning

# %%
def pullup(df, cols_to_pull):
    """Move some columns to the beginning of dataframe."""
    if isinstance(cols_to_pull, str):
        cols_to_pull = [cols_to_pull]
    cols_to_pull = list(cols_to_pull)
    remaining_cols = [col for col in df.columns if col not in set(cols_to_pull)]
    res = df[cols_to_pull + remaining_cols]
    return res

# %%
df = pullup(df, ['region', 'district', 'district_type'])

# %% [markdown]
# * Make `district` columns explicit

# %%
ix = (df['district'] == 'Агулам')
df.loc[ix, 'district'] = df[ix]['region'] + '. ' + df[ix]['district']

ix = (df['region'] == 'Рэспубліка') & ((df['district'] != 'Рэспубліка. Агулам'))
df.loc[ix, 'district'] = df[ix]['district'] + '. ' + df[ix]['district_type']

# %% [markdown]
# * show dataframe

# %%
df
# Out:
#          region                       district district_type     H_n   H_%  \
# 0      г. Менск                       Завадскі   раён гораду    4428  3.64
# 1      г. Менск                       Ленінскі   раён гораду    4068  3.37
# 2      г. Менск                      Маскоўскі   раён гораду    4753  3.21
# 3      г. Менск                   Кастрычніцкі   раён гораду    3077  3.36
# 4      г. Менск                    Партызанскі   раён гораду    1870  3.79
# ..          ...                            ...           ...     ...   ...
# 156  Рэспубліка  Гарадзенская вобласць. Агулам        Агулам   15691  2.27
# 157  Рэспубліка       Менская вобласць. Агулам        Агулам   32128  3.21
# 158  Рэспубліка   Магілёўская вобласць. Агулам        Агулам   27173  3.66
# 159  Рэспубліка               г. Менск. Агулам        Агулам   32585  3.33
# 160  Рэспубліка             Рэспубліка. Агулам        Агулам  201945  3.30
#
#         K_n   K_%      L_n    L_%     U_n  ...  electors  new_electors  \
# 0      9221  7.58    75931  62.42    3966  ...    166138         465.0
# 1      9952  8.24    77753  64.34    3451  ...    165567         713.0
# 2      9472  6.40    99879  67.50    3731  ...    198655         376.0
# 3      6569  7.17    61000  66.62    2365  ...    124966           5.0
# 4      3868  7.83    30542  61.85    1598  ...     67502         109.0
# ..      ...   ...      ...    ...     ...  ...       ...           ...
# 156   32755  4.75   592490  85.89    7092  ...    779638        2105.0
# 157   44155  4.41   858287  85.74   21763  ...   1116445        2019.0
# 158   25652  3.46   655396  88.30    7928  ...    816030        1420.0
# 159   69134  7.07   642119  65.69   26628  ...   1314164        3807.0
# 160  271426  4.44  5102478  83.47  102131  ...   7008682       16752.0
#
#      ballots  voted_n  voted_%  early_voters  home_voters  pp_voters  \
# 0     121646   121639    73.22         48601          837      72201
# 1     120995   120844    72.99         43996         2796      74052
# 2     148082   147972    74.49         60939         1791      85242
# 3      91631    91566    73.27         33855          962      56749
# 4      49385    49379    73.15         19231         2164      27984
# ..       ...      ...      ...           ...          ...        ...
# 156   689841   689824    88.48        286439        64395     338990
# 157  1001107  1001041    89.66        412680        97707     490654
# 158   742575   742263    90.96        298268        59198     384797
# 159   978800   977448    74.38        384285        20561     572602
# 160  6115690  6113013    87.22       2523981       436773    3152259
#
#      against_all   spoilt
# 0          27414    679.0
# 1          25263    357.0
# 2          29289    848.0
# 3          18165    390.0
# 4          10914    587.0
# ..           ...      ...
# 156        34169   7627.0
# 157        37552   7156.0
# 158        19443   6671.0
# 159       199056   7926.0
# 160       386225  48808.0
#
# [161 rows x 21 columns]

# %%
sg(df)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# ### check NANs and dtypes

# %%
df.isna().sum().to_frame('na_count').query('na_count > 0')
# Out:
#               na_count
# new_electors        42
# spoilt               2

# %%
df[df['spoilt'].isna()]
# Out:
#                 region        district district_type   H_n   H_%   K_n   K_%  \
# 48   Брэсцкая вобласць       Пружанскі          раён   457  1.25  1764  4.82
# 96  Віцебская вобласць  г. Наваполацак         горад  3970  5.90  2207  3.28
#
#       L_n    L_%   U_n  ...  electors  new_electors  ballots  voted_n  \
# 48  33871  92.62   243  ...     37801         166.0    36569    36569
# 96  55576  82.62  2085  ...     74676         334.0    67269    67269
#
#     voted_%  early_voters  home_voters  pp_voters  against_all  spoilt
# 48    96.74         14654         4268      17647          234     NaN
# 96    90.08         30263         2300      34706         3431     NaN
#
# [2 rows x 21 columns]

# %%
df[df['new_electors'].isna()]
# Out:
#                     region                       district district_type   H_n  \
# 5                 г. Менск                    Першамайскі   раён гораду  3873
# 21        Менская вобласць                  Маладзечанскі          раён  2325
# 22        Менская вобласць                     Мядзельскі          раён   871
# 26        Менская вобласць                     Смалявіцкі          раён   618
# 31        Менская вобласць                     Чэрвеньскі          раён   891
# 55   Гарадзенская вобласць                   Берастовіцкі          раён   167
# 60   Гарадзенская вобласць                     Зельвенскі          раён   192
# 61   Гарадзенская вобласць                        Іўеўскі          раён   277
# 62   Гарадзенская вобласць                      Карэліцкі          раён   108
# 66   Гарадзенская вобласць                     Астравецкі          раён   264
# 68   Гарадзенская вобласць                      Свіслацкі          раён   213
# 76      Віцебская вобласць                     Браслаўскі          раён   800
# 81      Віцебская вобласць                       Докшыцкі          раён   441
# 93      Віцебская вобласць                       Чашніцкі          раён   598
# 94      Віцебская вобласць                  Шаркоўшчынскі          раён   273
# 103   Магілёўская вобласць                       Быхаўскі          раён   365
# 108   Магілёўская вобласць                     Клімавіцкі          раён   250
# 111   Магілёўская вобласць                  Краснапольскі          раён    98
# 113   Магілёўская вобласць                     Круглянскі          раён   295
# 114   Магілёўская вобласць                     Магілёўскі          раён   489
# 121   Магілёўская вобласць                       Шклоўскі          раён   125
# 122   Магілёўская вобласць     Ленінскі раён г. Бабруйска   раён гораду  3927
# 123   Магілёўская вобласць  Першамайскі раён г. Бабруйска   раён гораду  2570
# 127    Гомельская вобласць                      Брагінскі          раён    92
# 128    Гомельская вобласць                Буда-Кашалёўскі          раён   208
# 130    Гомельская вобласць                      Гомельскі          раён  1936
# 131    Гомельская вобласць                      Добрушскі          раён   605
# 132    Гомельская вобласць                         Ельскі          раён   152
# 133    Гомельская вобласць                     Жыткавіцкі          раён   467
# 134    Гомельская вобласць                      Жлобінскі          раён  2650
# 135    Гомельская вобласць                   Калінкавіцкі          раён  1041
# 136    Гомельская вобласць                      Кармянскі          раён    45
# 137    Гомельская вобласць                      Лельчыцкі          раён   268
# 138    Гомельская вобласць                        Лоеўскі          раён   107
# 141    Гомельская вобласць                   Кастрычніцкі          раён   116
# 143    Гомельская вобласць                        Рэчыцкі          раён  2178
# 144    Гомельская вобласць                     Рагачоўскі          раён  1237
# 146    Гомельская вобласць                       Хойніцкі          раён    41
# 147    Гомельская вобласць                       Чачэрскі          раён    67
# 148    Гомельская вобласць       Чыгуначны раён г. Гомелю   раён гораду  8215
# 150    Гомельская вобласць         Савецкі раён г. Гомелю   раён гораду  8200
# 151    Гомельская вобласць      Цэнтральны раён г. Гомелю   раён гораду  5371
#
#       H_%   K_n   K_%    L_n    L_%   U_n  ...  electors  new_electors  \
# 5    3.20  8549  7.07  80881  66.89  3212  ...    158455           NaN
# 21   2.44  5531  5.81  77384  81.28  1360  ...    106959           NaN
# 22   4.26   531  2.60  17798  86.99   589  ...     22238           NaN
# 26   1.89  1266  3.88  28426  87.10   483  ...     35333           NaN
# 31   3.73   593  2.49  21437  89.85   206  ...     24979           NaN
# 55   1.42   208  1.77  10960  93.05   104  ...     12016           NaN
# 60   1.49   310  2.41  11966  93.08    76  ...     13194           NaN
# 61   1.38   336  1.67  18734  93.01   101  ...     20755           NaN
# 62   0.64   501  2.98  15946  94.89    81  ...     17455           NaN
# 66   1.43   328  1.77  17204  93.05   115  ...     19458           NaN
# 68   1.59   262  1.96  12438  93.12   122  ...     13729           NaN
# 76   4.05   272  1.38  17693  89.49    84  ...     20658           NaN
# 81   2.32   577  3.04  17355  91.45   151  ...     19632           NaN
# 93   2.47   644  2.66  22041  90.87    73  ...     25348           NaN
# 94   2.26   366  3.03  11177  92.39    74  ...     12429           NaN
# 103  1.69   298  1.38  20068  92.81   171  ...     22478           NaN
# 108  1.29   999  5.16  17777  91.74   102  ...     19852           NaN
# 111  1.39    68  0.97   6576  93.57    62  ...      7165           NaN
# 113  2.71   226  2.08  10121  93.09    72  ...     11028           NaN
# 114  1.49  1105  3.37  29641  90.52   308  ...     34252           NaN
# 121  0.59   576  2.74  20023  95.16    75  ...     21332           NaN
# 122  6.47  1802  2.97  53038  87.40   631  ...     69479           NaN
# 123  3.14  3010  3.68  72190  88.23  1097  ...     93010           NaN
# 127  1.02    38  0.42   8824  97.37    17  ...      9285           NaN
# 128  0.83    85  0.34  24389  97.61    44  ...     25892           NaN
# 130  3.68  1211  2.30  47104  89.55   591  ...     57156           NaN
# 131  2.06   331  1.13  27775  94.48   186  ...     30725           NaN
# 132  1.24    46  0.38  11902  97.48    51  ...     12462           NaN
# 133  1.81   407  1.58  24008  93.30   179  ...     27567           NaN
# 134  3.67  2596  3.60  62921  87.20  1024  ...     77566           NaN
# 135  2.38   459  1.05  40176  91.74   511  ...     46510           NaN
# 136  0.45   134  1.35   9684  97.43    21  ...     10198           NaN
# 137  1.41   146  0.77  18271  95.79    88  ...     19588           NaN
# 138  1.14    42  0.45   9025  96.31    55  ...      9559           NaN
# 141  1.08    94  0.88  10387  97.10    32  ...     11054           NaN
# 143  3.15  1916  2.77  62107  89.80  1210  ...     74200           NaN
# 144  3.01   916  2.23  36385  88.56   797  ...     43741           NaN
# 146  0.28    26  0.18  14423  98.10    43  ...     15030           NaN
# 147  0.61    39  0.36  10687  97.31    52  ...     11264           NaN
# 148  7.28  3591  3.18  90723  80.44  3280  ...    134043           NaN
# 150  7.47  3467  3.16  88924  80.96  2729  ...    131348           NaN
# 151  7.44  2421  3.35  57694  79.91  2188  ...     88143           NaN
#
#      ballots  voted_n  voted_%  early_voters  home_voters  pp_voters  \
# 5     121004   120919    76.31         47962         4469      68488
# 21     95208    95208    89.01         39362         7045      48801
# 22     20459    20459    92.00          8242         3730       8487
# 26     32637    32637    92.37         11924         4268      16445
# 31     23859    23859    95.52         10113         3242      10504
# 55     11779    11779    98.03          5437         1612       4730
# 60     12856    12856    97.44          6028         2220       4608
# 61     20141    20141    97.04          8373         1950       9818
# 62     16805    16805    96.28          7496         3970       5339
# 66     18489    18489    95.02          8023         2965       7501
# 68     13357    13357    97.29          5705         2738       4914
# 76     19772    19772    95.71          8297         2594       8881
# 81     18978    18977    96.66          7687         3518       7772
# 93     24255    24255    95.69         10871         2730      10654
# 94     12098    12098    97.34          4755         2230       5113
# 103    21658    21623    96.20          9985         1869       9769
# 108    19378    19378    97.61          9056         1400       8922
# 111     7028     7028    98.09          3238          637       3153
# 113    10875    10872    98.59          4485          940       5447
# 114    32747    32745    95.60         13035         4518      15192
# 121    21041    21041    98.64          8642         3153       9246
# 122    60684    60684    87.34         23263         3073      34348
# 123    81829    81824    87.97         31713         3153      46958
# 127     9062     9062    97.60          4330          497       4235
# 128    24987    24987    96.50         12691         1494      10802
# 130    52606    52601    92.03         21048         3474      28079
# 131    29400    29398    95.68         14035         1060      14303
# 132    12210    12210    97.98          5957          505       5748
# 133    25731    25731    93.34         11535         1217      12979
# 134    72158    72158    93.03         28539         2883      40736
# 135    43830    43792    94.16         18851         2656      22285
# 136     9939     9939    97.46          5028          631       4280
# 137    19074    19074    97.38          8521          981       9572
# 138     9371     9371    98.03          4690         1364       3317
# 141    10699    10697    96.77          5035         1270       4392
# 143    69161    69161    93.21         29408         8643      31110
# 144    41087    41085    93.93         17579         2760      20746
# 146    14702    14702    97.82          6684         1166       6852
# 147    10982    10982    97.50          5267          339       5376
# 148   112789   112784    84.14         44244         3162      65378
# 150   109912   109836    83.62         42026         3798      64012
# 151    72203    72197    81.91         28399         1292      42506
#
#      against_all  spoilt
# 5          23092  1312.0
# 21          6927  1681.0
# 22           654    16.0
# 26          1115   729.0
# 31           537   195.0
# 55           317    23.0
# 60           247    65.0
# 61           263   430.0
# 62           142    27.0
# 66           463   115.0
# 68           249    73.0
# 76           671   252.0
# 81           411    42.0
# 93           710   189.0
# 94           139    69.0
# 103          520   201.0
# 108          140   110.0
# 111          156    68.0
# 113          110    48.0
# 114          919   283.0
# 121          173    69.0
# 122          699   587.0
# 123         2324   633.0
# 127           51    40.0
# 128          138   123.0
# 130         1483   276.0
# 131          431    70.0
# 132           32    27.0
# 133          412   258.0
# 134         2586   381.0
# 135         1263   342.0
# 136           30    25.0
# 137          170   131.0
# 138          103    39.0
# 141           39    29.0
# 143          508  1242.0
# 144         1510   240.0
# 146          130    39.0
# 147          101    36.0
# 148         6466   509.0
# 150         4528  1988.0
# 151         3074  1449.0
#
# [42 rows x 21 columns]

# %% [markdown]
# * Fill missed values with 0

# %%
df = df.fillna(0, downcast='infer')

# %%
df.dtypes
# Out:
# region            object
# district          object
# district_type     object
# H_n                int64
# H_%              float64
# K_n                int64
# K_%              float64
# L_n                int64
# L_%              float64
# U_n                int64
# U_%              float64
# electors           int64
# new_electors       int64
# ballots            int64
# voted_n            int64
# voted_%          float64
# early_voters       int64
# home_voters        int64
# pp_voters          int64
# against_all        int64
# spoilt             int64
# dtype: object

# %% [markdown]
# ### save the dataset to `.csv` and `.xlsx`

# %%
out_dp = os.path.join('..', 'data', 'output')
os.makedirs(out_dp, exist_ok=True)

# %%
out_fp_csv = os.path.join(out_dp, 'Vybary_2015.csv')
df.to_csv(out_fp_csv, index=False)

# %%
out_fp_xlsx = os.path.join(out_dp, 'Vybary_2015.xlsx')
df.to_excel(out_fp_xlsx, index=False, freeze_panes=(1,0))
